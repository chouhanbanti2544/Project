# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\honey\anaconda3\lib\site-packages (1.4.2)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\honey\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\honey\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\honey\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\honey\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

r = requests.get('https://www.flipkart.com/q/best-laptops-under-rs-50000')
soup = BeautifulSoup(r.content,'html.parser')
containers = soup.find_all('div',{"class":"_2kHMtA"})
# print(containers)
print(len(containers)) 
print(type(containers),len(containers))
# Out:
# 24
# <class 'bs4.element.ResultSet'> 24

# %%
#container of first page

for container in containers:
    product = container.find_all('div',{'class':'_4rR01T'})
    print(product)
# Out:
# [<div class="_4rR01T">HP Laptop with Backlit Keyboard Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fr2512tu Lapt...</div>]
# [<div class="_4rR01T">MSI Modern 14 Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) Modern 14 B5M-242IN Thin and...</div>]
# [<div class="_4rR01T">HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq2144au Thin and Light Laptop</div>]
# [<div class="_4rR01T">HP OMEN Ryzen 7 Octa Core AMD R7-6800H - (16 GB/512 GB SSD/Windows 11 Home/8 GB Graphics/AMD Radeon RX...</div>]
# [<div class="_4rR01T">HP Pavilion x360 Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14-dy0212TU 2 in 1 Laptop</div>]
# [<div class="_4rR01T">HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/Windows 11 Home) 14s-fq1089au Thin and Light Laptop</div>]
# [<div class="_4rR01T">HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 14s-fq1092au Thin and Light Laptop</div>]
# [<div class="_4rR01T">MSI Ryzen 7 Octa Core 5700U - (8 GB/512 GB SSD/Windows 11 Home) Modern 15 A5M-280IN Notebook</div>]
# [<div class="_4rR01T">HP G8 Ryzen 5 Hexa Core 5500U 5th Gen - (8 GB/512 GB SSD/Windows 11 Home) 62Y30PA Laptop</div>]
# [<div class="_4rR01T">HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq2671TU Thin and Light Laptop</div>]
# [<div class="_4rR01T">MSI Delta 15 AMD Advantage Edition Ryzen 9 Octa Core 5900HX 5th Gen - (16 GB/1 TB SSD/Windows 11 Home/...</div>]
# [<div class="_4rR01T">HP Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) 15s-du3614TU Thin and Light Laptop</div>]
# [<div class="_4rR01T">HP Pavilion x360 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14-dh1181TU 2 in 1 Laptop</div>]
# [<div class="_4rR01T">HP 15s Ryzen 3 Dual Core 3250U - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) 15s-GR0012AU Laptop</div>]
# [<div class="_4rR01T">HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq2627TU Thin and Light Laptop</div>]
# [<div class="_4rR01T">HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-dy3501TU Thin and Light Laptop</div>]
# [<div class="_4rR01T">HP 15s Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) 15s-FQ2072TU Thin and Light Laptop</div>]
# [<div class="_4rR01T">MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/512 GB SSD/Windows 10 Home) Modern 14 B4MW-423IN Thin an...</div>]
# [<div class="_4rR01T">HP G8 Core i5 11th Gen - (8 GB/1 TB HDD/Windows 11 Home) 250 G8 Business Laptop</div>]
# [<div class="_4rR01T">HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) 15s-FR2006TU Thin and Light Laptop</div>]
# [<div class="_4rR01T">HP 15s Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/Windows 10 Home) 15s- EQ2042AU Thin and Light Laptop</div>]
# [<div class="_4rR01T">MSI Modern 15 Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 10 Home) Modern 15 A5M-065IN Thin and...</div>]
# [<div class="_4rR01T">HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 14s - dy2508TU Thin and Light Laptop</div>]
# [<div class="_4rR01T">HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s - dy2507TU Thin and Light Laptop</div>]

# %%
#container of first page

for container in containers:
    product = container.find_all('div',{'class':'_4rR01T'})
    print(product[0].text)
    break
    
# container is not a keyword   
# remove for all container access from all age
# Out:
# HP Laptop with Backlit Keyboard Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fr2512tu Lapt...

# %%
#container of first page

for container in containers:
    product = container.find_all('div',{'class':'_4rR01T'})
    print(product[0].text)
    
    print(type(product[0].text))
# Out:
# HP Laptop with Backlit Keyboard Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fr2512tu Lapt...
# <class 'str'>
# MSI Modern 14 Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) Modern 14 B5M-242IN Thin and...
# <class 'str'>
# HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq2144au Thin and Light Laptop
# <class 'str'>
# HP OMEN Ryzen 7 Octa Core AMD R7-6800H - (16 GB/512 GB SSD/Windows 11 Home/8 GB Graphics/AMD Radeon RX...
# <class 'str'>
# HP Pavilion x360 Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14-dy0212TU 2 in 1 Laptop
# <class 'str'>
# HP Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/Windows 11 Home) 14s-fq1089au Thin and Light Laptop
# <class 'str'>
# HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 14s-fq1092au Thin and Light Laptop
# <class 'str'>
# MSI Ryzen 7 Octa Core 5700U - (8 GB/512 GB SSD/Windows 11 Home) Modern 15 A5M-280IN Notebook
# <class 'str'>
# HP G8 Ryzen 5 Hexa Core 5500U 5th Gen - (8 GB/512 GB SSD/Windows 11 Home) 62Y30PA Laptop
# <class 'str'>
# HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq2671TU Thin and Light Laptop
# <class 'str'>
# MSI Delta 15 AMD Advantage Edition Ryzen 9 Octa Core 5900HX 5th Gen - (16 GB/1 TB SSD/Windows 11 Home/...
# <class 'str'>
# HP Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) 15s-du3614TU Thin and Light Laptop
# <class 'str'>
# HP Pavilion x360 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14-dh1181TU 2 in 1 Laptop
# <class 'str'>
# HP 15s Ryzen 3 Dual Core 3250U - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) 15s-GR0012AU Laptop
# <class 'str'>
# HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq2627TU Thin and Light Laptop
# <class 'str'>
# HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-dy3501TU Thin and Light Laptop
# <class 'str'>
# HP 15s Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) 15s-FQ2072TU Thin and Light Laptop
# <class 'str'>
# MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/512 GB SSD/Windows 10 Home) Modern 14 B4MW-423IN Thin an...
# <class 'str'>
# HP G8 Core i5 11th Gen - (8 GB/1 TB HDD/Windows 11 Home) 250 G8 Business Laptop
# <class 'str'>
# HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) 15s-FR2006TU Thin and Light Laptop
# <class 'str'>
# HP 15s Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/Windows 10 Home) 15s- EQ2042AU Thin and Light Laptop
# <class 'str'>
# MSI Modern 15 Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 10 Home) Modern 15 A5M-065IN Thin and...
# <class 'str'>
# HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 14s - dy2508TU Thin and Light Laptop
# <class 'str'>
# HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14s - dy2507TU Thin and Light Laptop
# <class 'str'>

# %%
#container of first page

for container in containers:
    product = container.find_all('div',{'class':'_4rR01T'})
    print(product[0].text.split('-'))
    break
    
# container is not a keyword   
# remove for all container access from all age
# when i split this  will convered in to 3 part
# Out:
# ['HP Laptop with Backlit Keyboard Core i3 11th Gen ', ' (8 GB/512 GB SSD/Windows 11 Home) 15s', 'fr2512tu Lapt...']

# %%
#container of first page

for container in containers:
    product = container.find_all('div',{'class':'_4rR01T'})
    print(product[0].text.split('-')[0])
    break

#[0]=[HP Pavilion Ryzen 5 Hexa Core AMD R5]
# container is not a keyword   
# remove for all container access from all age
# Out:
# HP Laptop with Backlit Keyboard Core i3 11th Gen

# %%
#container of first page

for container in containers:
    product = container.find_all('div',{'class':'_4rR01T'})
    print(product[0].text.split('-')[0])
  
#[0]=[HP Pavilion Ryzen 5 Hexa Core AMD R5]
# container is not a keyword   
# remove for all container access from all age
# Out:
# HP Laptop with Backlit Keyboard Core i3 11th Gen
# MSI Modern 14 Ryzen 5 Hexa Core 5500U
# HP Ryzen 5 Hexa Core 5500U
# HP OMEN Ryzen 7 Octa Core AMD R7
# HP Pavilion x360 Core i3 11th Gen
# HP Ryzen 3 Quad Core 5300U
# HP Ryzen 5 Hexa Core 5500U
# MSI Ryzen 7 Octa Core 5700U
# HP G8 Ryzen 5 Hexa Core 5500U 5th Gen
# HP Core i3 11th Gen
# MSI Delta 15 AMD Advantage Edition Ryzen 9 Octa Core 5900HX 5th Gen
# HP Core i3 11th Gen
# HP Pavilion x360 Core i3 10th Gen
# HP 15s Ryzen 3 Dual Core 3250U
# HP Core i3 11th Gen
# HP Core i3 11th Gen
# HP 15s Core i3 11th Gen
# MSI Modern 14 Ryzen 5 Hexa Core 4500U
# HP G8 Core i5 11th Gen
# HP Core i3 11th Gen
# HP 15s Ryzen 3 Quad Core 5300U
# MSI Modern 15 Ryzen 5 Hexa Core 5500U
# HP Core i3 11th Gen
# HP Core i3 11th Gen

# %%
#container of first page

for container in containers:
    product = container.find_all('div',{'class':'_4rR01T'})
    print(product[0].text.split('-')[0].strip())
  
#[0]=[HP Pavilion Ryzen 5 Hexa Core AMD R5]
# container is not a keyword   
# remove for all container access from all age
#find_all giving space in last strip is using to remove last space
# Out:
# HP Laptop with Backlit Keyboard Core i3 11th Gen
# MSI Modern 14 Ryzen 5 Hexa Core 5500U
# HP Ryzen 5 Hexa Core 5500U
# HP OMEN Ryzen 7 Octa Core AMD R7
# HP Pavilion x360 Core i3 11th Gen
# HP Ryzen 3 Quad Core 5300U
# HP Ryzen 5 Hexa Core 5500U
# MSI Ryzen 7 Octa Core 5700U
# HP G8 Ryzen 5 Hexa Core 5500U 5th Gen
# HP Core i3 11th Gen
# MSI Delta 15 AMD Advantage Edition Ryzen 9 Octa Core 5900HX 5th Gen
# HP Core i3 11th Gen
# HP Pavilion x360 Core i3 10th Gen
# HP 15s Ryzen 3 Dual Core 3250U
# HP Core i3 11th Gen
# HP Core i3 11th Gen
# HP 15s Core i3 11th Gen
# MSI Modern 14 Ryzen 5 Hexa Core 4500U
# HP G8 Core i5 11th Gen
# HP Core i3 11th Gen
# HP 15s Ryzen 3 Quad Core 5300U
# MSI Modern 15 Ryzen 5 Hexa Core 5500U
# HP Core i3 11th Gen
# HP Core i3 11th Gen

# %%
f = open('laaptops_info.csv','wb')
f.write('Productname,stars,Ratings,Reviews,currentprice,MRP,Processor,Ram,Storage,ImageURL\n'.encode())

   #finding product name
import re
for container in containers:
    product = container.find_all('div',{'class':'_4rR01T'})
    Productname = (product[0].text.split('-')[0].strip())
    
    
    #finding star
    star = container.find('div',{"class":"_3LWZlK"})
    try:
        stars = (star.text)
    except:
        stars = 0
        
    #finding rating and reviews
    Rating = container.find('span',{'class':'_2_R_DZ'})

    try:
        ratRev = re.findall('\d+,?\d*',Rating.get_text())
        Ratings =  ratRev[0].replace(',','')
        Reviews =  ratRev[1].replace(',','')
        
    except:
        Ratings = 0
        Reviews = 0
   
    #finding current price
    currentprices = container.find('div',{'class':'_30jeq3 _1_WHN1'})
    currentprice = currentprices.text.replace(',','')
    
    
    
    #finding mrp
    mrp = container.find('div',{'class':'_3I9_wc _27UcVY'})
    try:
        MRP = mrp.text.replace(',','')
    except:
        MRP = 0
    
    
    #find product feature info
    info = container.findAll('li',{'class':'rgWa7D'})
    Processor= info[0].text.replace(',','')
    Ram = info[1].text
    Storage = info[3].text
    
    
    Image = container.img
    ImageURL = Image.get('src')
    
    print(Productname,stars,Ratings,Reviews,currentprice,MRP,Processor,Ram,Storage,ImageURL)
    f.write(f"{Productname},{stars},{Ratings},{Reviews},{currentprice},{MRP},{Processor},{Ram},{Storage},{ImageURL}\n".encode())
    print('\n')
   
f.close()
# Out:
# HP Laptop with Backlit Keyboard Core i3 11th Gen 4.1 10 1 ₹45490 ₹51724 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/l/z/u/15s-fr2512tu-laptop-hp-original-imaggmeygbtemggf.jpeg?q=70
#
#
# MSI Modern 14 Ryzen 5 Hexa Core 5500U 4.4 2565 360 ₹45990 ₹61990 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/i/o/b/modern-14-b5m-notebook-msi-original-imaggmfqjsdatppv.jpeg?q=70
#
#
# HP Ryzen 5 Hexa Core 5500U 4.3 707 61 ₹50499 ₹56354 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/5/6/i/-original-imaggshd5zgfe8ev.jpeg?q=70
#
#
# HP OMEN Ryzen 7 Octa Core AMD R7 4.4 19 4 ₹104990 ₹124283 AMD Ryzen 7 Octa Core Processor 16 GB DDR5 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/c/s/a/16-n0049ax-gaming-laptop-hp-original-imaghwptyggvfjjd.jpeg?q=70
#
#
# HP Pavilion x360 Core i3 11th Gen 4.2 116 10 ₹47990 ₹58174 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 256 GB SSD https://rukminim1.flixcart.com/image/312/312/ktketu80/computer/r/f/r/14-dy0050tu-thin-and-light-laptop-hp-original-imag6w29bs32mq2j.jpeg?q=70
#
#
# HP Ryzen 3 Quad Core 5300U 4.3 1499 198 ₹39990 ₹48294 AMD Ryzen 3 Quad Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/5/k/i/-original-imaggsh8hmh4jmdz.jpeg?q=70
#
#
# HP Ryzen 5 Hexa Core 5500U 4.3 1449 155 ₹50999 ₹57042 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/5/k/i/-original-imaggsh8hmh4jmdz.jpeg?q=70
#
#
# MSI Ryzen 7 Octa Core 5700U 3.9 59 7 ₹52990 ₹78990 AMD Ryzen 7 Octa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/o/j/y/modern-15-a5m-280in-notebook-msi-original-imagghky6pgysr4f.jpeg?q=70
#
#
# HP G8 Ryzen 5 Hexa Core 5500U 5th Gen 5 4 1 ₹45500 ₹49695 AMD Ryzen 5 Hexa Core Processor (5th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/x/i/h/255-g8-laptop-hp-original-imagghdbs8mnge44.jpeg?q=70
#
#
# HP Core i3 11th Gen 4.2 75 6 ₹41490 ₹47834 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/l51d30w0/computer/4/a/i/15s-fq2671tu-thin-and-light-laptop-hp-original-imagfsxsgmkdcjsg.jpeg?q=70
#
#
# MSI Delta 15 AMD Advantage Edition Ryzen 9 Octa Core 5900HX 5th Gen 4.6 23 3 ₹125490 ₹188990 AMD Ryzen 9 Octa Core Processor (5th Gen) 16 GB DDR4 RAM 1 TB SSD https://rukminim1.flixcart.com/image/312/312/kxnl6kw0/computer/p/y/t/a5efk-083in-gaming-laptop-msi-original-imaga237dvrrnznh.jpeg?q=70
#
#
# HP Core i3 11th Gen 4 57 2 ₹43990 ₹52000 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 1 TB HDD|256 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/k/u/m/15s-du3614tu-thin-and-light-laptop-hp-original-imagghe6jcf76wgc.jpeg?q=70
#
#
# HP Pavilion x360 Core i3 10th Gen 4.5 614 74 ₹48629 ₹50098 Intel Core i3 Processor (10th Gen) 8 GB DDR4 RAM 256 GB SSD https://rukminim1.flixcart.com/image/312/312/kgtqhe80/computer/j/d/f/hp-original-imafwyzup42zw2bu.jpeg?q=70
#
#
# HP 15s Ryzen 3 Dual Core 3250U 4.3 4272 496 ₹45500 ₹52000 AMD Ryzen 3 Dual Core Processor 8 GB DDR4 RAM 1 TB HDD|256 GB SSD https://rukminim1.flixcart.com/image/312/312/kk2wl8w0/computer/z/u/5/hp-original-imafzgdgcbtxvjka.jpeg?q=70
#
#
# HP Core i3 11th Gen 4.2 532 58 ₹46500 ₹48000 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/kzrbiq80/computer/v/d/d/15s-fq2626tu-thin-and-light-laptop-hp-original-imagbpb2sztfprgz.jpeg?q=70
#
#
# HP Core i3 11th Gen 4.3 1515 142 ₹46900 ₹50892 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/kyt0ya80/computer/s/z/b/-original-imagayc6ahrmg8y7.jpeg?q=70
#
#
# HP 15s Core i3 11th Gen 4.3 539 66 ₹46900 ₹47500 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/kl5hh8w0/computer/c/j/8/hp-original-imagyckn3hqfgp4y.jpeg?q=70
#
#
# MSI Modern 14 Ryzen 5 Hexa Core 4500U 4.5 1383 208 ₹45990 ₹61990 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/ko0d6kw0/computer/t/m/1/modern-14-b4mw-410in-notebook-msi-original-imag2km2armfgmhp.jpeg?q=70
#
#
# HP G8 Core i5 11th Gen 3.8 18 0 ₹48999 ₹58548 Intel Core i5 Processor (11th Gen) 8 GB DDR4 RAM 1 TB HDD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/e/e/h/hp-250-g8-64q91pa-intel-i5-business-laptop-hp-original-imaghrs7ygrztvzc.jpeg?q=70
#
#
# HP Core i3 11th Gen 4.3 1347 139 ₹50000 ₹50774 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/kdoup3k0/computer/e/v/p/hp-original-imafujjhdwjjh9j8.jpeg?q=70
#
#
# HP 15s Ryzen 3 Quad Core 5300U 4.3 271 41 ₹48999 ₹50900 AMD Ryzen 3 Quad Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/k7531jk0/computer/e/a/h/hp-original-imafpfs893zu5mhb.jpeg?q=70
#
#
# MSI Modern 15 Ryzen 5 Hexa Core 5500U 4.4 2565 360 ₹47990 ₹69990 AMD Ryzen 5 Hexa Core Processor 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/xif0q/computer/z/a/q/-original-imagh3jvfcznrvcs.jpeg?q=70
#
#
# HP Core i3 11th Gen 4.3 2521 221 ₹40999 ₹49508 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 512 GB SSD https://rukminim1.flixcart.com/image/312/312/l5h2xe80/computer/h/i/p/14s-dy5005tu-thin-and-light-laptop-hp-original-imagg4rc7n75zqkp.jpeg?q=70
#
#
# HP Core i3 11th Gen 4.2 745 66 ₹40999 ₹47206 Intel Core i3 Processor (11th Gen) 8 GB DDR4 RAM 256 GB SSD https://rukminim1.flixcart.com/image/312/312/l5h2xe80/computer/h/i/p/14s-dy5005tu-thin-and-light-laptop-hp-original-imagg4rc7n75zqkp.jpeg?q=70

# %%
for container in containers:
    Ratings = container.find('span',{'class':'_2_R_DZ'})
    try:
        print(Ratings.get_text())
    except:
        print(Ratings)
        
    
#     rare = Ratings.get_text()
#     print(rare)
# Out:
# 10 Ratings & 1 Reviews
# 2,565 Ratings & 360 Reviews
# 707 Ratings & 61 Reviews
# 19 Ratings & 4 Reviews
# 116 Ratings & 10 Reviews
# 1,499 Ratings & 198 Reviews
# 1,449 Ratings & 155 Reviews
# 59 Ratings & 7 Reviews
# 4 Ratings & 1 Reviews
# 75 Ratings & 6 Reviews
# 23 Ratings & 3 Reviews
# 57 Ratings & 2 Reviews
# 614 Ratings & 74 Reviews
# 4,272 Ratings & 496 Reviews
# 532 Ratings & 58 Reviews
# 1,515 Ratings & 142 Reviews
# 539 Ratings & 66 Reviews
# 1,383 Ratings & 208 Reviews
# 18 Ratings & 0 Reviews
# 1,347 Ratings & 139 Reviews
# 271 Ratings & 41 Reviews
# 2,565 Ratings & 360 Reviews
# 2,521 Ratings & 221 Reviews
# 745 Ratings & 66 Reviews

# %%
import pandas as pd

# %%
pd.read_csv('laaptops_info.csv')
# Out:
#                                           Productname  stars  Ratings  \
# 0    HP Laptop with Backlit Keyboard Core i3 11th Gen    4.1       10
# 1               MSI Modern 14 Ryzen 5 Hexa Core 5500U    4.4     2565
# 2                          HP Ryzen 5 Hexa Core 5500U    4.3      707
# 3                    HP OMEN Ryzen 7 Octa Core AMD R7    4.4       19
# 4                   HP Pavilion x360 Core i3 11th Gen    4.2      116
# 5                          HP Ryzen 3 Quad Core 5300U    4.3     1499
# 6                          HP Ryzen 5 Hexa Core 5500U    4.3     1449
# 7                         MSI Ryzen 7 Octa Core 5700U    3.9       59
# 8               HP G8 Ryzen 5 Hexa Core 5500U 5th Gen    5.0        4
# 9                                 HP Core i3 11th Gen    4.2       75
# 10  MSI Delta 15 AMD Advantage Edition Ryzen 9 Oct...    4.6       23
# 11                                HP Core i3 11th Gen    4.0       57
# 12                  HP Pavilion x360 Core i3 10th Gen    4.5      614
# 13                     HP 15s Ryzen 3 Dual Core 3250U    4.3     4272
# 14                                HP Core i3 11th Gen    4.2      532
# 15                                HP Core i3 11th Gen    4.3     1515
# 16                            HP 15s Core i3 11th Gen    4.3      539
# 17              MSI Modern 14 Ryzen 5 Hexa Core 4500U    4.5     1383
# 18                             HP G8 Core i5 11th Gen    3.8       18
# 19                                HP Core i3 11th Gen    4.3     1347
# 20                     HP 15s Ryzen 3 Quad Core 5300U    4.3      271
# 21              MSI Modern 15 Ryzen 5 Hexa Core 5500U    4.4     2565
# 22                                HP Core i3 11th Gen    4.3     2521
# 23                                HP Core i3 11th Gen    4.2      745
#
#     Reviews currentprice      MRP                                  Processor  \
# 0         1       ₹45490   ₹51724         Intel Core i3 Processor (11th Gen)
# 1       360       ₹45990   ₹61990            AMD Ryzen 5 Hexa Core Processor
# 2        61       ₹50499   ₹56354            AMD Ryzen 5 Hexa Core Processor
# 3         4      ₹104990  ₹124283            AMD Ryzen 7 Octa Core Processor
# 4        10       ₹47990   ₹58174         Intel Core i3 Processor (11th Gen)
# 5       198       ₹39990   ₹48294            AMD Ryzen 3 Quad Core Processor
# 6       155       ₹50999   ₹57042            AMD Ryzen 5 Hexa Core Processor
# 7         7       ₹52990   ₹78990            AMD Ryzen 7 Octa Core Processor
# 8         1       ₹45500   ₹49695  AMD Ryzen 5 Hexa Core Processor (5th Gen)
# 9         6       ₹41490   ₹47834         Intel Core i3 Processor (11th Gen)
# 10        3      ₹125490  ₹188990  AMD Ryzen 9 Octa Core Processor (5th Gen)
# 11        2       ₹43990   ₹52000         Intel Core i3 Processor (11th Gen)
# 12       74       ₹48629   ₹50098         Intel Core i3 Processor (10th Gen)
# 13      496       ₹45500   ₹52000            AMD Ryzen 3 Dual Core Processor
# 14       58       ₹46500   ₹48000         Intel Core i3 Processor (11th Gen)
# 15      142       ₹46900   ₹50892         Intel Core i3 Processor (11th Gen)
# 16       66       ₹46900   ₹47500         Intel Core i3 Processor (11th Gen)
# 17      208       ₹45990   ₹61990            AMD Ryzen 5 Hexa Core Processor
# 18        0       ₹48999   ₹58548         Intel Core i5 Processor (11th Gen)
# 19      139       ₹50000   ₹50774         Intel Core i3 Processor (11th Gen)
# 20       41       ₹48999   ₹50900            AMD Ryzen 3 Quad Core Processor
# 21      360       ₹47990   ₹69990            AMD Ryzen 5 Hexa Core Processor
# 22      221       ₹40999   ₹49508         Intel Core i3 Processor (11th Gen)
# 23       66       ₹40999   ₹47206         Intel Core i3 Processor (11th Gen)
#
#                Ram              Storage  \
# 0    8 GB DDR4 RAM           512 GB SSD
# 1    8 GB DDR4 RAM           512 GB SSD
# 2    8 GB DDR4 RAM           512 GB SSD
# 3   16 GB DDR5 RAM           512 GB SSD
# 4    8 GB DDR4 RAM           256 GB SSD
# 5    8 GB DDR4 RAM           512 GB SSD
# 6    8 GB DDR4 RAM           512 GB SSD
# 7    8 GB DDR4 RAM           512 GB SSD
# 8    8 GB DDR4 RAM           512 GB SSD
# 9    8 GB DDR4 RAM           512 GB SSD
# 10  16 GB DDR4 RAM             1 TB SSD
# 11   8 GB DDR4 RAM  1 TB HDD|256 GB SSD
# 12   8 GB DDR4 RAM           256 GB SSD
# 13   8 GB DDR4 RAM  1 TB HDD|256 GB SSD
# 14   8 GB DDR4 RAM           512 GB SSD
# 15   8 GB DDR4 RAM           512 GB SSD
# 16   8 GB DDR4 RAM           512 GB SSD
# 17   8 GB DDR4 RAM           512 GB SSD
# 18   8 GB DDR4 RAM             1 TB HDD
# 19   8 GB DDR4 RAM           512 GB SSD
# 20   8 GB DDR4 RAM           512 GB SSD
# 21   8 GB DDR4 RAM           512 GB SSD
# 22   8 GB DDR4 RAM           512 GB SSD
# 23   8 GB DDR4 RAM           256 GB SSD
#
#                                              ImageURL
# 0   https://rukminim1.flixcart.com/image/312/312/x...
# 1   https://rukminim1.flixcart.com/image/312/312/x...
# 2   https://rukminim1.flixcart.com/image/312/312/x...
# 3   https://rukminim1.flixcart.com/image/312/312/x...
# 4   https://rukminim1.flixcart.com/image/312/312/k...
# 5   https://rukminim1.flixcart.com/image/312/312/x...
# 6   https://rukminim1.flixcart.com/image/312/312/x...
# 7   https://rukminim1.flixcart.com/image/312/312/x...
# 8   https://rukminim1.flixcart.com/image/312/312/x...
# 9   https://rukminim1.flixcart.com/image/312/312/l...
# 10  https://rukminim1.flixcart.com/image/312/312/k...
# 11  https://rukminim1.flixcart.com/image/312/312/x...
# 12  https://rukminim1.flixcart.com/image/312/312/k...
# 13  https://rukminim1.flixcart.com/image/312/312/k...
# 14  https://rukminim1.flixcart.com/image/312/312/k...
# 15  https://rukminim1.flixcart.com/image/312/312/k...
# 16  https://rukminim1.flixcart.com/image/312/312/k...
# 17  https://rukminim1.flixcart.com/image/312/312/k...
# 18  https://rukminim1.flixcart.com/image/312/312/x...
# 19  https://rukminim1.flixcart.com/image/312/312/k...
# 20  https://rukminim1.flixcart.com/image/312/312/k...
# 21  https://rukminim1.flixcart.com/image/312/312/x...
# 22  https://rukminim1.flixcart.com/image/312/312/l...
# 23  https://rukminim1.flixcart.com/image/312/312/l...
